# %%
from models import Image, Mask, Sample, PatchGenerator

# %%
data_path = "../../data_raw/pancreas"

# %%
wsi = Sample(slide=f"{data_path}/Pan_PNI2021chall_train_0001.svs", mask=Mask(f"{data_path}/Pan_PNI2021chall_train_0001_l1_mask.tif"))

# %%
plt.figure(figsize=(14,14))
plt.imshow(wsi.thumb(mask_overlay=True, max_width=2048))

# %%
plt.figure(figsize=(14,14))
plt.imshow(wsi.mask.thumb(max_width=2048))

# %%
patch_gen = PatchGenerator(wsi)

# %%
for patch in patch_gen.generate_patches(patch_size=(1024,1024)):
    cv.imwrite(f"{patch_path}images/{sample_name}_{i}.jpg", patch.image.read_block())
    cv.imwrite(f"{patch_path}masks/{sample_name}_{i}.png", patch.mask.read_block())
